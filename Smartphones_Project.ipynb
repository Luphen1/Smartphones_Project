# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Inspecting and loading dataframe
df = pd.read_excel(r"C:\Users\LUPHEN\Documents\Smartphone_Dataset.xlsx")

# %%
#See twenty rows in our dataframe
df.head(10)
# Out:
#   brand_name                                    model  price  rating  has_5g  \
# 0    oneplus                            OnePlus 11 5G  54999    89.0    True
# 1    oneplus                OnePlus Nord CE 2 Lite 5G  19989    81.0    True
# 2    samsung                    Samsung Galaxy A14 5G  16499    75.0    True
# 3   motorola                     Motorola Moto G62 5G  14999    81.0    True
# 4     realme                       Realme 10 Pro Plus  24999    82.0    True
# 5    samsung  Samsung Galaxy F23 5G (6GB RAM + 128GB)  16999    80.0    True
# 6      apple                          Apple iPhone 14  65999    81.0    True
# 7     xiaomi            Xiaomi Redmi Note 12 Pro Plus  29999    86.0    True
# 8    nothing                          Nothing Phone 1  26749    85.0    True
# 9    oneplus                       OnePlus Nord 2T 5G  28999    84.0    True
#
#    has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# ...

# %%
df.tail(10)
# Out:
#     brand_name                                    model   price  rating  \
# 970     realme  Realme Narzo 50i Prime (4GB RAM + 64GB)    8720    64.0
# 971       oppo                             Oppo Find X6   69990    89.0
# 972       itel                                itel A23s    4787     NaN
# 973     google                       Google Pixel 8 Pro   70990    80.0
# 974       vivo                            Vivo X Fold 2  119990     NaN
# 975   motorola               Motorola Moto Edge S30 Pro   34990    83.0
# 976      honor                              Honor X8 5G   14990    75.0
# 977       poco          POCO X4 GT 5G (8GB RAM + 256GB)   28990    85.0
# 978   motorola                     Motorola Moto G91 5G   19990    80.0
# 979    samsung                   Samsung Galaxy M52s 5G   24990    74.0
#
#      has_5g  has_nfc  has_ir_blaster processor_brand  num_cores  \
# 970   False    False           False           tiger        8.0
# ...

# %%
df.shape
# Out:
# (980, 26)

# %%
#Checking the context of my dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 980 non-null    object
#  1   model                      980 non-null    object
#  2   price                      980 non-null    int64
#  3   rating                     879 non-null    float64
#  4   has_5g                     980 non-null    bool
#  5   has_nfc                    980 non-null    bool
#  6   has_ir_blaster             980 non-null    bool
#  7   processor_brand            960 non-null    object
#  8   num_cores                  974 non-null    float64
#  9   processor_speed            938 non-null    float64
#  10  battery_capacity           969 non-null    float64
#  11  fast_charging_available    980 non-null    int64
#  12  fast_charging              769 non-null    float64
# ...

# %%
#Checked for any null values
df.isna().sum()
# Out:
# brand_name                     0
# model                          0
# price                          0
# rating                       101
# has_5g                         0
# has_nfc                        0
# has_ir_blaster                 0
# processor_brand               20
# num_cores                      6
# processor_speed               42
# battery_capacity              11
# fast_charging_available        0
# fast_charging                211
# ram_capacity                   0
# internal_memory                0
# screen_size                    0
# refresh_rate                   0
# num_rear_cameras               0
# num_front_cameras              4
# os                            14
# primary_camera_rear            0
# primary_camera_front           5
# extended_memory_available      0
# extended_upto                480
# resolution_width               0
# resolution_height              0
# dtype: int64

# %%
#Checked for duplicate values
#We have no duplicate values

df.duplicated().sum()
# Out:
# 0

# %%
#Handle null with the  mean value
rating_mean = df['rating'].mean()
rating_mean
# Out:
# 78.25824800910125

# %%
df['rating'] = df['rating'].fillna(78.25824800910125)
df['rating']
# Out:
# 0      89.0
# 1      81.0
# 2      75.0
# 3      81.0
# 4      82.0
#        ...
# 975    83.0
# 976    75.0
# 977    85.0
# 978    80.0
# 979    74.0
# Name: rating, Length: 980, dtype: float64

# %%
df['processor_brand'] = df['processor_brand'].fillna('unknown')
df['processor_brand']
# Out:
# 0      snapdragon
# 1      snapdragon
# 2          exynos
# 3      snapdragon
# 4       dimensity
#           ...
# 975    snapdragon
# 976    snapdragon
# 977     dimensity
# 978    snapdragon
# 979       unknown
# Name: processor_brand, Length: 980, dtype: object

# %%
num_cores_mean = df['num_cores'].mean()
num_cores_mean
# Out:
# 7.772073921971253

# %%
df['num_cores'] = df['num_cores'].fillna(7.772073921971253)
df['num_cores']
# Out:
# 0      8.0
# 1      8.0
# 2      8.0
# 3      8.0
# 4      8.0
#       ...
# 975    8.0
# 976    8.0
# 977    8.0
# 978    8.0
# 979    8.0
# Name: num_cores, Length: 980, dtype: float64

# %%
processor_speed_mean = df['processor_speed'].mean()
processor_speed_mean
# Out:
# 2.427217484008529

# %%
df['processor_speed'] = df['processor_speed'].fillna(2.427217484008529)
df['processor_speed']
# Out:
# 0      3.200000
# 1      2.200000
# 2      2.400000
# 3      2.200000
# 4      2.600000
#          ...
# 975    3.000000
# 976    2.200000
# 977    2.850000
# 978    2.200000
# 979    2.427217
# Name: processor_speed, Length: 980, dtype: float64

# %%
battery_capacity_mean = df['battery_capacity'].mean()
battery_capacity_mean
# Out:
# 4817.748194014448

# %%
 df['battery_capacity'] = df['battery_capacity'].fillna(4817.748194014448)
 df['battery_capacity']
# Out:
# 0      5000.0
# 1      5000.0
# 2      5000.0
# 3      5000.0
# 4      5000.0
#         ...
# 975    5000.0
# 976    5000.0
# 977    5080.0
# 978    5000.0
# 979    5000.0
# Name: battery_capacity, Length: 980, dtype: float64

# %%
fast_charging_mean = df['fast_charging'].mean()
fast_charging_mean
# Out:
# 46.1261378413524

# %%
df['fast_charging'] = df['fast_charging'].fillna(46.1261378413524)
df['fast_charging']
# Out:
# 0      100.000000
# 1       33.000000
# 2       15.000000
# 3       46.126138
# 4       67.000000
#           ...
# 975     68.000000
# 976     22.000000
# 977     67.000000
# 978     46.126138
# 979     46.126138
# Name: fast_charging, Length: 980, dtype: float64

# %%
num_front_cameras_mean = df['num_front_cameras'].mean()
num_front_cameras_mean
# Out:
# 1.0297131147540983

# %%
df['num_front_cameras'] = df['num_front_cameras'].fillna(1.0297131147540983)
df['num_front_cameras']
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 975    1.0
# 976    1.0
# 977    1.0
# 978    1.0
# 979    1.0
# Name: num_front_cameras, Length: 980, dtype: float64

# %%
df['os'] = df['os'].fillna('unknown')
df['os']
# Out:
# 0      android
# 1      android
# 2      android
# 3      android
# 4      android
#         ...
# 975    android
# 976    android
# 977    android
# 978    android
# 979    android
# Name: os, Length: 980, dtype: object

# %%
primary_camera_front_mean = df['primary_camera_front'].mean()
primary_camera_front_mean
# Out:
# 16.5891282051282

# %%
df['primary_camera_front'] = df['primary_camera_front'].fillna(16.5891282051282)
df['primary_camera_front']
# Out:
# 0      16.0
# 1      16.0
# 2      13.0
# 3      16.0
# 4      16.0
#        ...
# 975    16.0
# 976     8.0
# 977    16.0
# 978    32.0
# 979    32.0
# Name: primary_camera_front, Length: 980, dtype: float64

# %%
extended_upto_mean = df['extended_upto'].mean()
extended_upto_mean
# Out:
# 736.064

# %%
df['extended_upto'] = df['extended_upto'].fillna(736.064)
df['extended_upto']
# Out:
# 0       736.064
# 1      1024.000
# 2      1024.000
# 3      1024.000
# 4       736.064
#          ...
# 975     736.064
# 976    1024.000
# 977     736.064
# 978    1024.000
# 979    1024.000
# Name: extended_upto, Length: 980, dtype: float64

# %%
#Previewed dataframe after filling up the null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 980 non-null    object
#  1   model                      980 non-null    object
#  2   price                      980 non-null    int64
#  3   rating                     980 non-null    float64
#  4   has_5g                     980 non-null    bool
#  5   has_nfc                    980 non-null    bool
#  6   has_ir_blaster             980 non-null    bool
#  7   processor_brand            980 non-null    object
#  8   num_cores                  980 non-null    float64
#  9   processor_speed            980 non-null    float64
#  10  battery_capacity           980 non-null    float64
#  11  fast_charging_available    980 non-null    int64
#  12  fast_charging              980 non-null    float64
# ...

# %%
statistic_distribution = df.describe().T
statistic_distribution
# Out:
#                            count          mean           std      min  \
# price                      980.0  32520.504082  39531.812669  3499.00
# rating                     980.0     78.258248      7.010599    60.00
# num_cores                  980.0      7.772074      0.834276     4.00
# processor_speed            980.0      2.427217      0.454026     1.20
# battery_capacity           980.0   4817.748194   1003.852459  1821.00
# fast_charging_available    980.0      0.854082      0.353205     0.00
# fast_charging              980.0     46.126138     30.360092    10.00
# ram_capacity               980.0      6.560204      2.744378     1.00
# internal_memory            980.0    141.036735    107.134516     8.00
# screen_size                980.0      6.536765      0.349162     3.54
# refresh_rate               980.0     92.256122     28.988052    60.00
# num_rear_cameras           980.0      2.814286      0.776441     1.00
# ...

# %%
#Checked for outliers using boxplot
sns.boxplot(data=df , y = 'price')
plt.title('Outliers')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Check outliers using IQR(interquatile Range)


Q3 = 35491.50
Q1 = 12999.000
Q3,Q1
# Out:
# (35491.5, 12999.0)

# %%
IQR = Q3 - Q1
IQR = 35491.50 - 12999.000
IQR
# Out:
# 22492.5

# %%
lower_limit = Q1 - IQR * 1.5
lower_limit = 12999.000 - 22492.5 * 1.5
lower_limit
# Out:
# -20739.75

# %%
upper_limit = Q3 + IQR * 1.5
upper_limit = 35491.50 + 22492.5 * 1.5
upper_limit
# Out:
# 69230.25

# %%
no_outliers_df = df[(df.price > lower_limit) & (df.price < upper_limit)]
no_outliers_df
# Out:
#     brand_name                            model  price  rating  has_5g  \
# 0      oneplus                    OnePlus 11 5G  54999    89.0    True
# 1      oneplus        OnePlus Nord CE 2 Lite 5G  19989    81.0    True
# 2      samsung            Samsung Galaxy A14 5G  16499    75.0    True
# 3     motorola             Motorola Moto G62 5G  14999    81.0    True
# 4       realme               Realme 10 Pro Plus  24999    82.0    True
# ..         ...                              ...    ...     ...     ...
# 975   motorola       Motorola Moto Edge S30 Pro  34990    83.0    True
# 976      honor                      Honor X8 5G  14990    75.0    True
# 977       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0    True
# 978   motorola             Motorola Moto G91 5G  19990    80.0    True
# 979    samsung           Samsung Galaxy M52s 5G  24990    74.0    True
#
#      has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# ...

# %%
#After removing outliers
sns.boxplot(data = no_outliers_df , y = 'price')
plt.title('Cleaned')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
no_outliers_df.shape
# Out:
# (873, 26)

# %%
outliers_df = df[(df.price < lower_limit) | (df.price > upper_limit)]
outliers_df
# Out:
#     brand_name                             model   price     rating  has_5g  \
# 14     samsung       Samsung Galaxy S23 Ultra 5G  114990  78.258248    True
# 27       apple           Apple iPhone 14 Pro Max  129990  76.000000    True
# 29     oneplus                    OnePlus 11 Pro   69999  78.258248    True
# 37     samsung       Samsung Galaxy S22 Ultra 5G   91999  78.258248    True
# 56       apple              Apple iPhone 14 Plus   74999  82.000000    True
# ..         ...                               ...     ...        ...     ...
# 951     huawei  Huawei Mate 30 RS Porsche Design  214990  78.258248    True
# 954     huawei                     Huawei Mate X  169000  78.258248    True
# 971       oppo                      Oppo Find X6   69990  89.000000    True
# 973     google                Google Pixel 8 Pro   70990  80.000000    True
# 974       vivo                     Vivo X Fold 2  119990  78.258248    True
#
# ...

# %%
#outliers visualization
sns.boxplot(data = outliers_df , y = 'price')
plt.title('Outliers')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
no_outliers_df.nunique()
# Out:
# brand_name                    42
# model                        873
# price                        307
# rating                        31
# has_5g                         2
# has_nfc                        2
# has_ir_blaster                 2
# processor_brand               14
# num_cores                      4
# processor_speed               34
# battery_capacity              79
# fast_charging_available        2
# fast_charging                 31
# ram_capacity                   8
# internal_memory                7
# screen_size                   64
# refresh_rate                   5
# num_rear_cameras               4
# num_front_cameras              3
# os                             4
# primary_camera_rear           16
# primary_camera_front          21
# extended_memory_available      2
# extended_upto                  8
# resolution_width              24
# resolution_height             48
# dtype: int64

# %%
#Ready for exploratory data analysis
#During the analysis I would be working with 'no_outliers_df'

#1.What was the smartphone prices across different top ten brands?
#dist_price = no_outliers_df.groupby('brand_name')['price'].sum().reset_index().sort_values('price',ascending=False)
#dist_price
dist_price =  no_outliers_df.groupby('brand_name')['price'].sum().reset_index().nlargest(10,'price')
dist_price
# Out:
#    brand_name    price
# 40     xiaomi  2631831
# 34    samsung  2567384
# 39       vivo  2192907
# 29       oppo  1798025
# 32     realme  1693758
# 28    oneplus  1291063
# 24   motorola  1253196
# 14       iqoo   969660
# 0       apple   815660
# 31       poco   757647

# %%
sns.barplot(data = dist_price, y ='brand_name', x ='price')
plt.title('Distribution price by brand')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#2.Is there a correlation between the price of a smartphone and its battery capacity,RAM capacity and internal memory,and the price and rating.
#There are 
corr_relationship = no_outliers_df[['fast_charging','battery_capacity','ram_capacity','internal_memory','price','rating']].corr()
corr_relationship
# Out:
#                   fast_charging  battery_capacity  ram_capacity  \
# fast_charging          1.000000         -0.086425      0.465693
# battery_capacity      -0.086425          1.000000      0.081733
# ram_capacity           0.465693          0.081733      1.000000
# internal_memory        0.412791          0.118084      0.799291
# price                  0.522781         -0.053866      0.670985
# rating                 0.394756         -0.010217      0.709286
#
#                   internal_memory     price    rating
# fast_charging            0.412791  0.522781  0.394756
# battery_capacity         0.118084 -0.053866 -0.010217
# ram_capacity             0.799291  0.670985  0.709286
# internal_memory          1.000000  0.613873  0.614854
# price                    0.613873  1.000000  0.611739
# rating                   0.614854  0.611739  1.000000

# %%
sns.heatmap(corr_relationship, annot=True, cmap='Spectral', fmt=".2f")
plt.title('Correlation Relationship')
plt.show()

# %%
#Visualized price distribution across the dataframe
sns.histplot(data = no_outliers_df , x ='price',kde=True,color='green')
plt.title('Price distribution')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Statistic information within the dataframe
correlation_relationship = no_outliers_df.describe().T
correlation_relationship
# Out:
#                            count          mean           std      min  \
# price                      873.0  22488.634593  13834.010523  3499.00
# rating                     873.0     77.944697      7.134209    60.00
# num_cores                  873.0      7.800426      0.830387     4.00
# processor_speed            873.0      2.365831      0.430281     1.20
# battery_capacity           873.0   4864.830453   1025.984559  1821.00
# fast_charging_available    873.0      0.843070      0.363943     0.00
# fast_charging              873.0     45.272853     30.748540    10.00
# ram_capacity               873.0      6.234822      2.510725     1.00
# internal_memory            873.0    121.301260     63.685525     8.00
# screen_size                873.0      6.512039      0.306105     3.54
# refresh_rate               873.0     90.450172     27.922938    60.00
# num_rear_cameras           873.0      2.784651      0.785121     1.00
# ...

# %%
#4.What percentage of smartphones have fast charging available?
total_fast_charging = no_outliers_df['fast_charging'].sum()
total_fast_charging
total_phones = len('no_outliers_df')
total_phones
(total_fast_charging,total_phones)
percent_of_fast_charging_phones = (total_fast_charging / total_phones).round(3) * 100
percent_of_fast_charging_phones
# Out:
# 282308.6

# %%
#5.Analyzed the impact of processor brand on performance and rating.

processor_brand_stats = no_outliers_df.groupby('processor_brand')['rating'].mean().reset_index().sort_values('rating',ascending=False).round(3)
processor_brand_stats
# Out:
#    processor_brand  rating
# 9       snapdragon  81.085
# 1        dimensity  80.996
# 2           exynos  79.463
# 4           google  79.000
# 3           fusion  78.258
# 7         mediatek  78.258
# 10      spreadtrum  78.258
# 6            kirin  73.500
# 0           bionic  73.217
# 5            helio  72.826
# 12          unisoc  69.936
# 13         unknown  69.567
# 11           tiger  69.085
# 8          sc9863a  61.000

# %%
#Analyze the impact of processor brand on performance and rating.
sns.barplot(data =processor_brand_stats , y ='processor_brand', x = 'rating')
plt.title('Precessor brand performances')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#6.Analyze the performance differences between smartphones with different operating systems.
# Analyze the performance differences by operating system
os_performance_stats = no_outliers_df.groupby('os')[['price','rating']].agg(['mean','sum']).reset_index()
# Renaming columns for clarity
os_performance_stats.columns = ['operating_system', 'average_price', 'total_price', 'average_rating', 'total_rating']
# Sorting values
os_performance_stats = os_performance_stats.sort_values(['average_price', 'total_price', 'average_rating', 'total_rating'], ascending=False)
os_performance_stats
# Out:
#   operating_system  average_price  total_price  average_rating  total_rating
# 1              ios   50978.750000       815660       73.532281   1176.516496
# 3          unknown   30996.000000        92988       83.086083    249.258248
# 2            other   30305.571429       212139       79.073785    553.516496
# 0          android   21855.715466     18511791       78.000506  66066.428896

# %%
#Visualized average price for each operating system.
sns.barplot(data =os_performance_stats, x = 'operating_system' , y = 'average_price')
plt.title('Average Price by operating system')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(data =os_performance_stats, x = 'operating_system' , y = 'total_price')
plt.title('Total Price by Operating system')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(data =os_performance_stats, x = 'operating_system' , y = 'average_rating')
plt.title('Operating system by average rating')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(data =os_performance_stats, x = 'operating_system' , y = 'total_rating')
plt.title('Total rating by Operating system')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#7.How does processor speeds and the number of cores vary across different processor brands?
processor_stats = no_outliers_df.groupby('processor_brand')[['processor_speed','num_cores']].agg(['mean', 'count']).reset_index()
processor_stats.columns = ['processor_brand','average_speed','num_of_precessor','average_num_cores','num_of_cores']
processor_stats.columns 
performance_dist = processor_stats.columns .sort_values(['processor_brand','average_speed','num_of_precessor','average_num_cores','num_of_cores'], ascending=False)
performance_dist
(processor_stats)
# Out:
#    processor_brand  average_speed  num_of_precessor  average_num_cores  \
# 0           bionic       3.020000                15           6.000000
# 1        dimensity       2.520546               173           8.000000
# 2           exynos       2.388509                41           8.000000
# 3           fusion       2.370000                 1           4.000000
# 4           google       2.621942                 6           8.000000
# 5            helio       2.115146               201           7.781095
# 6            kirin       2.280000                 2           8.000000
# 7         mediatek       1.500000                 1           4.000000
# 8          sc9863a       1.600000                 2           8.000000
# 9       snapdragon       2.519375               358           7.943497
# 10      spreadtrum       1.350000                 4           4.000000
# 11           tiger       1.858333                24           7.166667
# ...

# %%
#Visualized average price for each operating system.
sns.regplot(data =processor_stats, y = 'average_speed' , x = 'num_of_precessor')
plt.title('Relationship by avg speed and number of precessor')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#8.What was the average price of smartphones model with 5G? 
# Filter the DataFrame for 5G smartphones
smartphones_with_5g = no_outliers_df[no_outliers_df['has_5g'] == True]

# Calculate the average price of 5G smartphones
average_price_5g = smartphones_with_5g['price'].mean().round(2)

average_price_5g
# Group by model for 5G smartphones and calculate the mean price
average_price_5g_per_model = smartphones_with_5g.groupby('model')['price'].mean().reset_index().sort_values('price',ascending=False)
average_price_5g_per_model.head

#Find top ten model price
top_ten_model_price = average_price_5g_per_model.nlargest(10,'price')
top_ten_model_price
# Out:
#                                     model    price
# 2                 Apple iPhone 12 (256GB)  67999.0
# 8                         Apple iPhone 14  65999.0
# 128  OnePlus 10 Pro 5G (12GB RAM + 256GB)  65499.0
# 424            iQOO 11 (16GB RAM + 256GB)  64999.0
# 7                    Apple iPhone 13 Mini  64900.0
# 137                         OnePlus 9 Pro  64800.0
# 299            Samsung Galaxy S22 Plus 5G  64449.0
# 12                         Asus ZenFone 9  63990.0
# 6                         Apple iPhone 13  62999.0
# 423                  ZTE Axon 40 Ultra 5G  61990.0

# %%
#Visualized average price for smartphone model with 5G.
sns.barplot(data=top_ten_model_price, y = 'model' , x = 'price')
plt.title('Average price by model with 5g')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#9.What was the average price of smartphones model without 5G? 
# Filter the DataFrame for 5G smartphones
smartphones_without_5g = no_outliers_df[no_outliers_df['has_5g'] == False]

# Calculate the average price of model without 5G smartphones
average_price_without_5g = smartphones_with_5g['price'].mean().round(2)

average_price_without_5g
# Group by model for 5G smartphones and calculate the mean price
average_price_without_5g = smartphones_with_5g.groupby('model')['price'].mean().reset_index().sort_values('price',ascending=False)

average_price_without_5g.head(30)

#Find top ten model price
top_ten_model_price = average_price_5g_per_model.nlargest(10,'price')
top_ten_model_price
# Out:
#                             model    price
# 26              Huawei P50 Pro 4G  60999.0
# 258               Sharp Aquos R5G  59990.0
# 253   Samsung Galaxy Note 10 Plus  58999.0
# 2                 Apple iPhone 7s  52990.0
# 1         Apple iPhone 11 (128GB)  46999.0
# 254       Samsung Galaxy S10 Plus  42999.0
# 255            Samsung Galaxy S20  41999.0
# 252   Samsung Galaxy Note 10 Lite  39999.0
# 230  Samsung Galaxy A9 Pro (2019)  39990.0
# 4            Apple iPhone SE 2020  39900.0

# %%
#Visualized average price for smartphone model without 5G.
sns.barplot(data=top_ten_model_price, y = 'model' , x = 'price')
plt.title('Average price by model without 5g')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#10.Are there any relationship between smartphones camera?
#Visualized the relationship between the primary_camera_rear & primary_camera_front 
sns.regplot(data= no_outliers_df, y = 'primary_camera_rear' , x = 'primary_camera_front')
plt.title('Camera relationship')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#11.Are there any relationship between smartphones resolution width and height?
#Visualized the relationship between the resolution_width and resolution_height 
sns.regplot(data= no_outliers_df, y = 'resolution_width' , x = 'resolution_height')
plt.title('Resolution relationship')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
